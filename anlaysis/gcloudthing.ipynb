# %%
import os
from importlib import reload

os.chdir('C:\\Users\\ka021\\Documents\\repos\\Dev_Germline_cancer_analysis_2023')
import tools.kterra as kt

# %%
reload(kt)
# Out:
# <module 'tools.kterra' from 'c:\\Users\\ka021\\Documents\\repos\\Dev_Germline_cancer_analysis_2023\\tools\\kterra.py'>

# %%
project = "aldubayan-lab-dfci"
workspace = "KAnderson_PC_Germline_Analysis_WES"
bucket = "fc-394ae7b8-0dad-4d5f-a8cb-b9d74d23f954"

# %%
kt.fc_workspaces
# Out:
#                                                    accessLevel  \
# name
# TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA               READER
# REBC_methods_only                                       READER
# Renal1000_regional                                   NO ACCESS
# TARGET_CCSK_hg38_OpenAccess_GDCDR-12-0_DATA             READER
# TCGA_DLBC_OpenAccess_V1-0_DATA                          READER
# ...                                                        ...
# copy_test                                               READER
# BDC-PIC-SURE API R Examples                             READER
# KMeli_erv_te_ccle_geneKO_nih_regional                   READER
# Irbaz_Davidcopy_Docetaxel-Cabazitaxel_Trial_Ana...      READER
# e                                                       READER
#
#                                                                   namespace  \
# name
# TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA              broad-firecloud-tcga
# ...

# %%
WS = kt.Workspace(project, workspace)
gclient = kt.clients("aldubayan-lab-dfci")
gbucket = gclient.get_bucket(bucket)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ka021\api\anaconda3\envs\py3.11\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'KAnderson_PC_Germline_Analysis_WES'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ...

# %%
blobs = submission.list_blobs(delimiter='/')

# %%
[ws for ws in kt.fc_workspaces.index if ws.startswith('KA')]
# Out:
# ['KAnderson_PC_Germline_Analysis_WES',
#  'KAnderson_PC_Germline_Analysis_Storage',
#  'KAnderson_PCGermline_CohortScale_Dev',
#  'KAnderson_PCGermline_SampleScale_Dev',
#  'KAnderson_Multi-Ancestry-PRS_WES_1KG']

# %%
kt.fc_workspaces
# Out:
#                                                    accessLevel  \
# name
# TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA               READER
# REBC_methods_only                                       READER
# Renal1000_regional                                   NO ACCESS
# TARGET_CCSK_hg38_OpenAccess_GDCDR-12-0_DATA             READER
# TCGA_DLBC_OpenAccess_V1-0_DATA                          READER
# ...                                                        ...
# copy_test                                               READER
# BDC-PIC-SURE API R Examples                             READER
# KMeli_erv_te_ccle_geneKO_nih_regional                   READER
# Irbaz_Davidcopy_Docetaxel-Cabazitaxel_Trial_Ana...      READER
# e                                                       READER
#
#                                                                   namespace  \
# name
# TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA              broad-firecloud-tcga
# ...

# %%
blobs.prefixes
# Out:
# {'model_files/', 'notebooks/', 'submissions/'}
